# %% [markdown]
# # Importing Packages

# %%
# !pip install aisdc
# Out:
# Collecting aisdc
#   Downloading aisdc-1.1.2-py3-none-any.whl (88 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.6/88.6 kB 1.1 MB/s eta 0:00:00
# Collecting dictdiffer~=0.9.0 (from aisdc)
#   Downloading dictdiffer-0.9.0-py2.py3-none-any.whl (16 kB)
# Collecting fpdf~=1.7.2 (from aisdc)
#   Downloading fpdf-1.7.2.tar.gz (39 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: joblib~=1.3 in /usr/local/lib/python3.10/dist-packages (from aisdc) (1.3.2)
# Collecting multiprocess~=0.70.15 (from aisdc)
#   Downloading multiprocess-0.70.15-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 3.0 MB/s eta 0:00:00
# Requirement already satisfied: numpy~=1.23.1 in /usr/local/lib/python3.10/dist-packages (from aisdc) (1.23.5)
# Requirement already satisfied: pandas~=1.5.3 in /usr/local/lib/python3.10/dist-packages (from aisdc) (1.5.3)
# Collecting scikit-learn~=1.1.3 (from aisdc)
#   Downloading scikit_learn-1.1.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (30.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 30.5/30.5 MB 34.9 MB/s eta 0:00:00
# Requirement already satisfied: scipy~=1.10 in /usr/local/lib/python3.10/dist-packages (from aisdc) (1.11.4)
# Collecting uuid~=1.30 (from aisdc)
#   Downloading uuid-1.30.tar.gz (5.8 kB)
#   Preparing metadata (setup.py) ... done
# Collecting pypdf~=3.16 (from aisdc)
#   Downloading pypdf-3.17.1-py3-none-any.whl (277 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 277.6/277.6 kB 33.5 MB/s eta 0:00:00
# Collecting xgboost~=1.7.6 (from aisdc)
#   Downloading xgboost-1.7.6-py3-none-manylinux2014_x86_64.whl (200.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.3/200.3 MB 6.8 MB/s eta 0:00:00
# Collecting statsmodels==0.13.5 (from aisdc)
#   Downloading statsmodels-0.13.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (9.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 66.6 MB/s eta 0:00:00
# Collecting acro==0.4.3 (from aisdc)
#   Downloading acro-0.4.3-py3-none-any.whl (36 kB)
# Collecting tensorflow~=2.12.0 (from aisdc)
#   Downloading tensorflow-2.12.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (585.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 585.9/585.9 MB 1.6 MB/s eta 0:00:00
# Collecting tensorflow-privacy==0.8.10 (from aisdc)
#   Downloading tensorflow_privacy-0.8.10-py3-none-any.whl (365 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 365.2/365.2 kB 35.7 MB/s eta 0:00:00
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from acro==0.4.3->aisdc) (4.9.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from acro==0.4.3->aisdc) (3.7.1)
# Requirement already satisfied: openpyxl in /usr/local/lib/python3.10/dist-packages (from acro==0.4.3->aisdc) (3.1.2)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from acro==0.4.3->aisdc) (6.0.1)
# Requirement already satisfied: patsy>=0.5.2 in /usr/local/lib/python3.10/dist-packages (from statsmodels==0.13.5->aisdc) (0.5.3)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.10/dist-packages (from statsmodels==0.13.5->aisdc) (23.2)
# Requirement already satisfied: absl-py==1.*,>=1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow-privacy==0.8.10->aisdc) (1.4.0)
# Collecting attrs~=21.4 (from tensorflow-privacy==0.8.10->aisdc)
#   Downloading attrs-21.4.0-py2.py3-none-any.whl (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 kB 9.7 MB/s eta 0:00:00
# Requirement already satisfied: dm-tree==0.1.8 in /usr/local/lib/python3.10/dist-packages (from tensorflow-privacy==0.8.10->aisdc) (0.1.8)
# Collecting dp-accounting==0.4.2 (from tensorflow-privacy==0.8.10->aisdc)
#   Downloading dp_accounting-0.4.2-py3-none-any.whl (104 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.6/104.6 kB 16.0 MB/s eta 0:00:00
# Collecting immutabledict~=2.2 (from tensorflow-privacy==0.8.10->aisdc)
#   Downloading immutabledict-2.2.5-py3-none-any.whl (4.1 kB)
# Collecting packaging>=21.3 (from statsmodels==0.13.5->aisdc)
#   Downloading packaging-22.0-py3-none-any.whl (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.6/42.6 kB 6.7 MB/s eta 0:00:00
# Collecting parameterized~=0.8 (from tensorflow-privacy==0.8.10->aisdc)
#   Downloading parameterized-0.9.0-py2.py3-none-any.whl (20 kB)
# Requirement already satisfied: tensorflow-datasets~=4.5 in /usr/local/lib/python3.10/dist-packages (from tensorflow-privacy==0.8.10->aisdc) (4.9.3)
# Requirement already satisfied: tensorflow-estimator~=2.4 in /usr/local/lib/python3.10/dist-packages (from tensorflow-privacy==0.8.10->aisdc) (2.14.0)
# Collecting tensorflow-probability~=0.20.0 (from tensorflow-privacy==0.8.10->aisdc)
#   Downloading tensorflow_probability-0.20.1-py2.py3-none-any.whl (6.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 108.4 MB/s eta 0:00:00
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn~=1.1.3->aisdc) (3.2.0)
# Requirement already satisfied: mpmath~=1.2 in /usr/local/lib/python3.10/dist-packages (from dp-accounting==0.4.2->tensorflow-privacy==0.8.10->aisdc) (1.3.0)
# Collecting dill>=0.3.7 (from multiprocess~=0.70.15->aisdc)
#   Downloading dill-0.3.7-py3-none-any.whl (115 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 17.9 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas~=1.5.3->aisdc) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas~=1.5.3->aisdc) (2023.3.post1)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.12.0->aisdc) (1.6.3)
# Requirement already satisfied: flatbuffers>=2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.12.0->aisdc) (23.5.26)
# Collecting gast<=0.4.0,>=0.2.1 (from tensorflow~=2.12.0->aisdc)
#   Downloading gast-0.4.0-py3-none-any.whl (9.8 kB)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.12.0->aisdc) (0.2.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.12.0->aisdc) (1.59.3)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.12.0->aisdc) (3.9.0)
# Requirement already satisfied: jax>=0.3.15 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.12.0->aisdc) (0.4.20)
# Collecting keras<2.13,>=2.12.0 (from tensorflow~=2.12.0->aisdc)
#   Downloading keras-2.12.0-py2.py3-none-any.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 105.0 MB/s eta 0:00:00
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.12.0->aisdc) (16.0.6)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.12.0->aisdc) (3.3.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.12.0->aisdc) (3.20.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.12.0->aisdc) (67.7.2)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.12.0->aisdc) (1.16.0)
# Collecting tensorboard<2.13,>=2.12 (from tensorflow~=2.12.0->aisdc)
#   Downloading tensorboard-2.12.3-py3-none-any.whl (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 102.0 MB/s eta 0:00:00
# Collecting tensorflow-estimator~=2.4 (from tensorflow-privacy==0.8.10->aisdc)
#   Downloading tensorflow_estimator-2.12.0-py2.py3-none-any.whl (440 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 440.7/440.7 kB 57.2 MB/s eta 0:00:00
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.12.0->aisdc) (2.3.0)
# Requirement already satisfied: typing-extensions<4.6.0,>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.12.0->aisdc) (4.5.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.12.0->aisdc) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.12.0->aisdc) (0.34.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow~=2.12.0->aisdc) (0.42.0)
# Requirement already satisfied: ml-dtypes>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from jax>=0.3.15->tensorflow~=2.12.0->aisdc) (0.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->acro==0.4.3->aisdc) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->acro==0.4.3->aisdc) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->acro==0.4.3->aisdc) (4.45.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->acro==0.4.3->aisdc) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->acro==0.4.3->aisdc) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->acro==0.4.3->aisdc) (3.1.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow~=2.12.0->aisdc) (2.17.3)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow~=2.12.0->aisdc) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow~=2.12.0->aisdc) (3.5.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow~=2.12.0->aisdc) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow~=2.12.0->aisdc) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow~=2.12.0->aisdc) (3.0.1)
# Requirement already satisfied: array-record in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets~=4.5->tensorflow-privacy==0.8.10->aisdc) (0.5.0)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets~=4.5->tensorflow-privacy==0.8.10->aisdc) (8.1.7)
# Requirement already satisfied: etils[enp,epath,etree]>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets~=4.5->tensorflow-privacy==0.8.10->aisdc) (1.5.2)
# Requirement already satisfied: promise in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets~=4.5->tensorflow-privacy==0.8.10->aisdc) (2.3)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets~=4.5->tensorflow-privacy==0.8.10->aisdc) (5.9.5)
# Requirement already satisfied: tensorflow-metadata in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets~=4.5->tensorflow-privacy==0.8.10->aisdc) (1.14.0)
# Requirement already satisfied: toml in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets~=4.5->tensorflow-privacy==0.8.10->aisdc) (0.10.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets~=4.5->tensorflow-privacy==0.8.10->aisdc) (4.66.1)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from tensorflow-probability~=0.20.0->tensorflow-privacy==0.8.10->aisdc) (4.4.2)
# Requirement already satisfied: cloudpickle>=1.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow-probability~=0.20.0->tensorflow-privacy==0.8.10->aisdc) (2.2.1)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.10/dist-packages (from openpyxl->acro==0.4.3->aisdc) (1.1.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from etils[enp,epath,etree]>=0.9.0->tensorflow-datasets~=4.5->tensorflow-privacy==0.8.10->aisdc) (2023.6.0)
# Requirement already satisfied: importlib_resources in /usr/local/lib/python3.10/dist-packages (from etils[enp,epath,etree]>=0.9.0->tensorflow-datasets~=4.5->tensorflow-privacy==0.8.10->aisdc) (6.1.1)
# Requirement already satisfied: zipp in /usr/local/lib/python3.10/dist-packages (from etils[enp,epath,etree]>=0.9.0->tensorflow-datasets~=4.5->tensorflow-privacy==0.8.10->aisdc) (3.17.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow~=2.12.0->aisdc) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow~=2.12.0->aisdc) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow~=2.12.0->aisdc) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow~=2.12.0->aisdc) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow~=2.12.0->aisdc) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow~=2.12.0->aisdc) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow~=2.12.0->aisdc) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow~=2.12.0->aisdc) (2023.11.17)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.13,>=2.12->tensorflow~=2.12.0->aisdc) (2.1.3)
# Requirement already satisfied: googleapis-common-protos<2,>=1.52.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow-metadata->tensorflow-datasets~=4.5->tensorflow-privacy==0.8.10->aisdc) (1.61.0)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow~=2.12.0->aisdc) (0.5.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow~=2.12.0->aisdc) (3.2.2)
# Building wheels for collected packages: fpdf, uuid
#   Building wheel for fpdf (setup.py) ... done
#   Created wheel for fpdf: filename=fpdf-1.7.2-py2.py3-none-any.whl size=40703 sha256=bde090ddb175664c1c8a925c0452115aa4e8a2d6ea1547fb91b98a18546dc785
#   Stored in directory: /root/.cache/pip/wheels/f9/95/ba/f418094659025eb9611f17cbcaf2334236bf39a0c3453ea455
#   Building wheel for uuid (setup.py) ... done
#   Created wheel for uuid: filename=uuid-1.30-py3-none-any.whl size=6479 sha256=8265ce7111800d266084a9f7e85638a3df7394f5b8b7ec05c75cab969d213c0e
#   Stored in directory: /root/.cache/pip/wheels/ed/08/9e/f0a977dfe55051a07e21af89200125d65f1efa60cbac61ed88
# Successfully built fpdf uuid
# Installing collected packages: uuid, fpdf, dictdiffer, tensorflow-estimator, pypdf, parameterized, packaging, keras, immutabledict, gast, dill, attrs, xgboost, tensorflow-probability, scikit-learn, multiprocess, dp-accounting, statsmodels, tensorboard, acro, tensorflow, tensorflow-privacy, aisdc
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.14.0
#     Uninstalling tensorflow-estimator-2.14.0:
#       Successfully uninstalled tensorflow-estimator-2.14.0
#   Attempting uninstall: packaging
#     Found existing installation: packaging 23.2
#     Uninstalling packaging-23.2:
#       Successfully uninstalled packaging-23.2
#   Attempting uninstall: keras
#     Found existing installation: keras 2.14.0
#     Uninstalling keras-2.14.0:
#       Successfully uninstalled keras-2.14.0
#   Attempting uninstall: gast
#     Found existing installation: gast 0.5.4
#     Uninstalling gast-0.5.4:
#       Successfully uninstalled gast-0.5.4
#   Attempting uninstall: attrs
#     Found existing installation: attrs 23.1.0
#     Uninstalling attrs-23.1.0:
#       Successfully uninstalled attrs-23.1.0
#   Attempting uninstall: xgboost
#     Found existing installation: xgboost 2.0.2
#     Uninstalling xgboost-2.0.2:
#       Successfully uninstalled xgboost-2.0.2
#   Attempting uninstall: tensorflow-probability
#     Found existing installation: tensorflow-probability 0.22.0
#     Uninstalling tensorflow-probability-0.22.0:
#       Successfully uninstalled tensorflow-probability-0.22.0
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.2.2
#     Uninstalling scikit-learn-1.2.2:
#       Successfully uninstalled scikit-learn-1.2.2
#   Attempting uninstall: statsmodels
#     Found existing installation: statsmodels 0.14.0
#     Uninstalling statsmodels-0.14.0:
#       Successfully uninstalled statsmodels-0.14.0
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.14.1
#     Uninstalling tensorboard-2.14.1:
#       Successfully uninstalled tensorboard-2.14.1
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.14.0
#     Uninstalling tensorflow-2.14.0:
#       Successfully uninstalled tensorflow-2.14.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# lida 0.0.10 requires fastapi, which is not installed.
# lida 0.0.10 requires kaleido, which is not installed.
# lida 0.0.10 requires python-multipart, which is not installed.
# lida 0.0.10 requires uvicorn, which is not installed.
# bigframes 0.15.0 requires scikit-learn>=1.2.2, but you have scikit-learn 1.1.3 which is incompatible.
# jsonschema 4.19.2 requires attrs>=22.2.0, but you have attrs 21.4.0 which is incompatible.
# plotnine 0.12.4 requires statsmodels>=0.14.0, but you have statsmodels 0.13.5 which is incompatible.
# referencing 0.31.1 requires attrs>=22.2.0, but you have attrs 21.4.0 which is incompatible.
# Successfully installed acro-0.4.3 aisdc-1.1.2 attrs-21.4.0 dictdiffer-0.9.0 dill-0.3.7 dp-accounting-0.4.2 fpdf-1.7.2 gast-0.4.0 immutabledict-2.2.5 keras-2.12.0 multiprocess-0.70.15 packaging-22.0 parameterized-0.9.0 pypdf-3.17.1 scikit-learn-1.1.3 statsmodels-0.13.5 tensorboard-2.12.3 tensorflow-2.12.1 tensorflow-estimator-2.12.0 tensorflow-privacy-0.8.10 tensorflow-probability-0.20.1 uuid-1.30 xgboost-1.7.6

# %%
import os
import sys
import pylab as plt
import numpy as np
import logging
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
import pandas as pd
from sklearn.impute import KNNImputer
from sklearn import datasets
from sklearn import svm
from sklearn.model_selection import train_test_split
from sklearn.datasets import make_classification
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix, f1_score
from os.path import expanduser
from aisdc.safemodel.classifiers import SafeSVC
from sklearn.model_selection import GridSearchCV

# %% [markdown]
# # Data preperation

# %% [markdown]
# ## Loading train data

# %%
train_data = pd.read_csv('/content/drive/MyDrive/ADNI/ADNI_train_volumes.tsv')
train_data = train_data.drop(columns=['Unnamed: 0', 'session_id', 'examination_date', 'earliest_time','rh.aparc.volume','lh.aparc.volume'])
#data = data.set_index('participant_id')
#data[~data.index.duplicated(keep='first')]
train_data = train_data.drop(columns=['participant_id', 'Measure:volume'])

diagnosis_mapping = {'MCI': 0, 'CN': 0, 'AD': 1, 0.666667: 0}
train_data['diagnosis'] = train_data['diagnosis'].map(diagnosis_mapping)

train_data = train_data[(train_data['diagnosis'] == 0) | (train_data['diagnosis'] == 1)]

# %% [markdown]
# ## Loading test data

# %%
test_data = pd.read_csv('/content/drive/MyDrive/ADNI/ADNI_test_volumes.tsv')
test_data = test_data.drop(columns=['Unnamed: 0', 'Unnamed: 0.1', 'session_id','participant_id','rh.aparc.volume','lh.aparc.volume'])
diagnosis_mapping = {'MCI': 0, 'CN': 0, 'AD': 1}
test_data['diagnosis'] = test_data['diagnosis'].map(diagnosis_mapping)
test_data = test_data[(test_data['diagnosis'] == 0) | (test_data['diagnosis'] == 1)]

# %% [markdown]
# ## Cleaning data

# %%
# Making sure both train and test having same features
common_columns = set(train_data.columns).intersection(set(test_data.columns))
train_data = train_data[common_columns]
test_data = test_data[common_columns]

# %%
# Imputing missing values using KNN
imputer = KNNImputer(n_neighbors=3)
train_data = pd.DataFrame(imputer.fit_transform(train_data), columns=train_data.columns)
test_data = pd.DataFrame(imputer.fit_transform(test_data), columns=test_data.columns)

# %% [markdown]
# ## Split data

# %%
X_train = train_data.drop(columns=['diagnosis'])
X_test = test_data.drop(columns=['diagnosis'])
y_train = train_data['diagnosis']
y_test = test_data['diagnosis']

# %% [markdown]
# # SVM Model

# %% [markdown]
# ## SVM Hyperparameter Optimisation

# %%
svm = SVC()

param_grid = {
    'kernel': ['linear', 'rbf'],
    'C': [0.1, 1, 10],
    'gamma': [0.1, 1, 'scale']
}

grid_search = GridSearchCV(estimator=svm, param_grid=param_grid, cv=3, scoring='f1')
grid_search.fit(X_train, y_train)

best_params = grid_search.best_params_
best_score = grid_search.best_score_

# %%
print(best_params)

# %%
print(best_score)

# %% [markdown]
# ## Final SVM Model & Evaluation

# %%
clf = svm.SVC(kernel='linear', gamma=3, C=7)
clf.fit(X_train, y_train)
predictions = clf.predict(X_test)

# %%
clf = svm.SVC(kernel='linear', gamma=2)
clf.fit(X_train, y_train)
predictions = clf.predict(X_test)

# %%
accuracy = accuracy_score(y_test, predictions)
print(f"Accuracy: {accuracy}")
f1 = f1_score(y_test, predictions)
print(f"F1-Score: {f1}")

# %%
conf_matrix = confusion_matrix(y_test, predictions)
conf_matrix
